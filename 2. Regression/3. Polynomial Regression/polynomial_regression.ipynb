# %% [markdown]
# # Polynomial Regression

# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Importing the dataset

# %%
data = pd.read_csv(r'Position_Salaries.csv')

X = data.iloc[:,1:-1].values
y = data.iloc[:,-1].values

# %%
plt.plot(X, y)

# %% [markdown]
# ## Training the Linear Regression model on the whole dataset

# %%
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(X, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# ## Training the Polynomial Regression model on the whole dataset

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_reg2 = PolynomialFeatures(degree=2)
X_poly2 = poly_reg2.fit_transform(X)

poly_lin_reg_d2 = LinearRegression()
poly_lin_reg_d2.fit(X_poly2, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_reg4 = PolynomialFeatures(degree=4)
X_poly4 = poly_reg4.fit_transform(X)

poly_lin_reg_d4 = LinearRegression()
poly_lin_reg_d4.fit(X_poly4, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# ## Visualising the Linear Regression results

# %%
plt.scatter(X, y,color = 'red')
plt.plot(X, lin_reg.predict(X),color = 'blue')
plt.title('Truth or bluff')
plt.xlabel('Position level')
plt.ylabel('Salary')
# Out:
# Text(0, 0.5, 'Salary')

# %% [markdown]
# ## Visualising the Polynomial Regression results

# %%
plt.scatter(X, y,color = 'red')
plt.plot(X, poly_lin_reg_d2.predict(X_poly2),color = 'blue')
plt.title('Salary vs Position Level')
plt.xlabel('Position level')
plt.ylabel('Salary')
# Out:
# Text(0, 0.5, 'Salary')

# %% [markdown]
# ## Visualising the Polynomial Regression results (for higher resolution and smoother curve)

# %%
plt.scatter(X, y,color = 'red')
plt.plot(X, poly_lin_reg_d4.predict(X_poly4),color = 'blue')
plt.title('Salary vs Position Level')
plt.xlabel('Position level')
plt.ylabel('Salary')
# Out:
# Text(0, 0.5, 'Salary')

# %% [markdown]
# ## Predicting a new result with Linear Regression

# %%
lin_reg.predict([[6.5]])
# Out:
# array([330378.78787879])

# %% [markdown]
# ## Predicting a new result with Polynomial Regression

# %%
poly_lin_reg_d2.predict(poly_reg2.transform([[6.5]]))
# Out:
# array([189498.10606061])

# %%
poly_lin_reg_d4.predict(poly_reg4.transform([[6.5]]))
# Out:
# array([158862.45265153])
